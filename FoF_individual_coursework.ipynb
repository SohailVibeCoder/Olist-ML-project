# %% [markdown]
# <a href="https://colab.research.google.com/github/SohailVibeCoder/Olist-ML-project/blob/main/FoF_individual_coursework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <u>**TASK 1**</u>

# %% [markdown]
# Question 1

# %%
#FAIR PRICE OF BOND K
# C=5% of £1000 = £50
CFfivetofourteen= sum(50 / (1.08**t) for t in range(5, 15))


CFone=50/1.04
CFtwo=50/1.05**2
CFthree=50/1.06**3
CFfour=50/1.07**4
CFfifteen=1050/1.08**15

priceK=CFone+CFtwo+CFthree+CFfour+CFfivetofourteen+CFfifteen
print(f"Fair price of bond K is {priceK} GBP")

#FAIR PRICE OF BOND L
priceL=500/(1.1)**15
print(f"Fair price of bond L is {priceL} GBP")

#FAIR PRICE OF BOND K
# C=20% of £2000 = £400
CFfivetonineteen= sum(400 / (1.2**t) for t in range(5, 20))

CFoneM=400/1.1
CFtwoM=400/1.12**2
CFthreeM=400/1.14**3
CFfourM=400/1.16**4
CFtwenty=2400/1.2**20

priceM=CFoneM+CFtwoM+CFthreeM+CFfourM+CFfivetonineteen+CFtwenty
print(f"Fair price of bond M is {priceM} GBP")
# Out:
# Fair price of bond K is 751.1634191138087 GBP
# Fair price of bond L is 119.69602468458167 GBP
# Fair price of bond M is 2137.9251331292744 GBP

# %% [markdown]
# Question 3

# %%
# !pip install numpy_financial

# %%
import numpy_financial as npf

#YTM FOR BOND K

YTMK=round(npf.rate(15,50,-751.16,1000),4)
print(f"YTM of bond K is {100*YTMK}%")

#YTM FOR BOND L

YTML=round((500/119.7)**(1/15)-1,4)
print(f"YTM of bond L is {100*YTML}%")

#YTM FOR BOND M
YTMM=round(npf.rate(20,400,-2137.93,2000),4)
print(f"YTM of bond M is {100*YTMM}%")
# Out:
# YTM of bond K is 7.89%
# YTM of bond L is 10.0%
# YTM of bond M is 18.67%

# %% [markdown]
# Question 5b

# %%
# NEW PRICE OF BOND K
# C=5% of £1000 = £50
# Spot rates decreased by 0.25%
CFfivetofourteen = sum(50 / (1.0775**t) for t in range(5, 15))


CFone = 50 / 1.0375
CFtwo = 50 / 1.0475**2
CFthree = 50 / 1.0575**3
CFfour = 50 / 1.0675**4
CFfifteen = 1050 / 1.0775**15

NpriceK = round(CFone + CFtwo + CFthree + CFfour + CFfivetofourteen + CFfifteen, 2)
print(f"New price of bond K is {NpriceK} GBP")

# NEW PRICE OF BOND L
NpriceL = round(500 / (1.0975)**15, 3)
print(f"New price of bond L is {NpriceL} GBP")

# NEW PRICE OF BOND M
CFfivetonineteen = sum(400 / (1.1975**t) for t in range(5, 20))

CFoneM = 400 / 1.0975
CFtwoM = 400 / 1.1175**2
CFthreeM = 400 / 1.1375**3
CFfourM = 400 / 1.1575**4
CFtwenty = 2400 / 1.1975**20

NpriceM = round(CFoneM + CFtwoM + CFthreeM + CFfourM + CFfivetonineteen + CFtwenty, 2)
print(f"New price of bond M is {NpriceM} GBP")

exactK=NpriceK-priceK
exactL=NpriceL-priceL
exactM=NpriceM-priceM
print(f"Exact price change of bond K is {exactK} GBP")
print(f"Exact price change of bond L is {exactL} GBP")
print(f"Exact price change of bond M is {exactM} GBP")
# Out:
# New price of bond K is 768.99 GBP
# New price of bond L is 123.852 GBP
# New price of bond M is 2163.58 GBP
# Exact price change of bond K is 17.826580886191323 GBP
# Exact price change of bond L is 4.155975315418331 GBP
# Exact price change of bond M is 25.654866870725527 GBP

# %% [markdown]
# <u>**TASK 2**</u>

# %% [markdown]
# Question 1

# %%
from google.colab import drive
import os
import pandas as pd
import numpy as np

drive.mount('/content/drive')

os.chdir("/content/drive/MyDrive/")

crsp_monthly=pd.read_csv("crsp_monthly_subsample.csv")


# Convert date to datetime format
crsp_monthly['date'] = pd.to_datetime(crsp_monthly['date'])

# Clean price and return columns
crsp_monthly['prc'] = crsp_monthly['prc'].abs()
crsp_monthly['ret'] = pd.to_numeric(crsp_monthly['ret'], errors='coerce')
crsp_monthly.drop_duplicates(inplace=True)


crsp_monthly.to_csv("crsp_monthly.csv", index=False)
crsp_monthly


ff5_data = pd.read_csv("F-F_Research_Data_5_Factors_2x3.csv", skiprows=3, nrows=748)
# Rename first column to 'date'
ff5_data.rename(columns={ff5_data.columns[0]: 'date',
                         ff5_data.columns[1]: 'mktrf'}, inplace=True)
# Make all other columns lowercase
ff5_data.columns = [col.lower() for col in ff5_data.columns]
# Convert date to datetime format assuming that the data is valid as of the end of the month
ff5_data['date'] = pd.to_datetime(ff5_data['date'], format='%Y%m') + pd.offsets.MonthEnd(0)
ff5_data.to_csv("ff5_data.csv", index=False)




# Import Momentum factor returns data
# Note: careful with skiprows and nrows parameters to get the correct data
# - inspect the CSV file to determine these values
mom_data = pd.read_csv( "F-F_Momentum_Factor.csv", skiprows=13, nrows=1186)
mom_data.rename(columns={mom_data.columns[0]: 'date',
                         mom_data.columns[1]: 'mom'}, inplace=True)
# Convert date to datetime format assuming that the data is valid as of the end of the month
mom_data['date'] = pd.to_datetime(mom_data['date'], format='%Y%m') + pd.offsets.MonthEnd(0)
mom_data.to_csv("mom_data.csv", index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Merge FF5 and Momentum data
factor_data = pd.merge(ff5_data, mom_data, on='date', how='left')
factor_data.to_csv("factor_data.csv", index=False)
# Since FF5 data are in percentages, convert them to decimals
factor_data[['mktrf', 'smb', 'hml', 'rmw', 'cma', 'mom', 'rf']] = factor_data[['mktrf', 'smb', 'hml', 'rmw', 'cma','mom', 'rf']] / 100

# %%
start_date = '2015-01-01'
end_date = '2024-12-31'

date=(factor_data['date'] >= start_date) & (factor_data['date'] <= end_date)
factor_data=factor_data[date]
factor_data.to_csv("factor_data_filtered.csv",index=False)

# %%
factor_cols = ['mktrf', 'smb', 'hml', 'rmw', 'cma', 'rf', 'mom']
avg_realised_monthly_ret=factor_data[factor_cols].mean()
print("Table B1:")
print(avg_realised_monthly_ret)
# Out:
# Table B1:
# mktrf    0.009820
# smb     -0.001664
# hml     -0.001841
# rmw      0.003903
# cma     -0.000866
# rf       0.001395
# mom      0.002009
# dtype: float64

# %% [markdown]
# Question 2

# %%
avg_realised_monthly_ret_stock = crsp_monthly.groupby('permno')['ret'].mean()
print("Table B2:")
print(avg_realised_monthly_ret_stock)
# Out:
# Table B2:
# permno
# 10026    0.006283
# 10032    0.014102
# 10044   -0.006478
# 10065    0.012091
# 10104    0.014750
# 10107    0.021769
# 10318    0.010662
# 10333    0.017095
# 12079    0.010284
# 21020   -0.001801
# Name: ret, dtype: float64

# %% [markdown]
# Question 3

# %%
# Merge on year and month
# - convert date to yearmonth variable
crsp_monthly['yearmonth'] = crsp_monthly['date'].dt.to_period('M')
factor_data['yearmonth'] = factor_data['date'].dt.to_period('M')

# - perform the merge
crsp_factors = pd.merge(crsp_monthly, factor_data.drop(columns=['date']), on='yearmonth', how='left')
crsp_factors.to_csv("crsp_factors.csv", index=False)
print(crsp_factors.shape)
print(crsp_factors['date'].min())
print(crsp_factors['date'].max())
# Compute excess returns for individual stocks
# - denote excess returns as 'retex'
crsp_factors['retex'] = crsp_factors['ret'] - crsp_factors['rf']

avgexcessreturns_stock = crsp_factors.groupby('permno')['retex'].mean()
print("Table B3:")
print(avgexcessreturns_stock)
# Out:
# (1200, 16)
# 2015-01-30 00:00:00
# 2024-12-31 00:00:00
# Table B3:
# permno
# 10026    0.004888
# 10032    0.012707
# 10044   -0.007873
# 10065    0.010696
# 10104    0.013355
# 10107    0.020374
# 10318    0.009267
# 10333    0.015700
# 12079    0.008889
# 21020   -0.003196
# Name: retex, dtype: float64

# %% [markdown]
# Question 4

# %%
return_stats = crsp_factors.groupby('permno').agg(
    mean_ret=('ret', 'mean'),
    mean_retex=('retex', 'mean'),
    std_ret=('ret', 'std'),
    std_retex=('retex', 'std')
)

# %%
# Compute monthly Sharpe ratios of individual stocks
return_stats['sharpe_ratio_MON'] = return_stats['mean_retex'] / return_stats['std_ret']
# Compute annualised Sharpe ratios
return_stats['sharpe_ratio_ANN'] = return_stats['sharpe_ratio_MON'] * np.sqrt(12)

return_stats
# Out:
#         mean_ret  mean_retex   std_ret  std_retex  sharpe_ratio_MON  \
# permno
# 10026   0.006283    0.004888  0.063984   0.064001          0.076390
# 10032   0.014102    0.012707  0.076791   0.076742          0.165472
# 10044  -0.006478   -0.007873  0.107124   0.107379         -0.073498
# 10065   0.012091    0.010696  0.046701   0.046624          0.229023
# 10104   0.014750    0.013355  0.071858   0.071684          0.185845
# 10107   0.021769    0.020374  0.063172   0.063197          0.322522
# 10318   0.010662    0.009267  0.074134   0.074131          0.124999
# 10333   0.017095    0.015700  0.214573   0.214508          0.073167
# 12079   0.010284    0.008889  0.096507   0.096479          0.092109
# 21020  -0.001801   -0.003196  0.118026   0.118027         -0.027078
#
#         sharpe_ratio_ANN
# permno
# 10026           0.264621
# 10032           0.573213
# 10044          -0.254606
# 10065           0.793359
# 10104           0.643786
# 10107           1.117247
# ...

# %%
sharpe_ratio_annual = return_stats[['sharpe_ratio_ANN']].reset_index()
print("Table B4:")
print(sharpe_ratio_annual)
# Out:
# Table B4:
#    permno  sharpe_ratio_ANN
# 0   10026          0.264621
# 1   10032          0.573213
# 2   10044         -0.254606
# 3   10065          0.793359
# 4   10104          0.643786
# 5   10107          1.117247
# 6   10318          0.433011
# 7   10333          0.253458
# 8   12079          0.319075
# 9   21020         -0.093801

# %% [markdown]
# Question 5

# %%
crsp_factors = crsp_factors.sort_values(by=['date', 'permno']).copy()


crsp_factors['w_ew'] = 1 / crsp_factors.groupby('date')['permno'].transform('count')


crsp_factors['ret_ew'] = (crsp_factors['ret'] * crsp_factors['w_ew']).groupby(crsp_factors['date']).transform('sum')


portfolio_stats = crsp_factors.groupby('date')[['ret_ew', 'rf']].first().reset_index()


rf_mean_subsample = factor_data[
    (factor_data['date'] >= "2015-01-01") & (factor_data['date'] <= "2024-12-31")
]['rf'].mean()


ew_mean = portfolio_stats['ret_ew'].mean()
ew_std  = portfolio_stats['ret_ew'].std()
ew_mean_ex = ew_mean - rf_mean_subsample

ew_monthly_sharpe_ratio_portfolio = ew_mean_ex / ew_std
ew_annualized_sharpe_ratio_portfolio = ew_monthly_sharpe_ratio_portfolio * np.sqrt(12)

print("Equally weighted mean monthly excess return:", ew_mean_ex)
print("Annualized Sharpe ratio:", ew_annualized_sharpe_ratio_portfolio)
# Out:
# Equally weighted mean monthly excess return: 0.00848051583333333
# Annualized Sharpe ratio: 0.5379846446243807

# %% [markdown]
# Question 6

# %%
# Compute market capitalization
crsp_factors['mktcap'] = crsp_factors['prc'] * crsp_factors['shrout'] / 1e6  # in billions

# - get lagged market capitalization
crsp_factors['mktcap_l1'] = crsp_factors.groupby('permno')['mktcap'].shift(1)
# - value weighted portfolio weights
crsp_factors['w_vw'] = crsp_factors['mktcap_l1'] / crsp_factors.groupby('date')['mktcap_l1'].transform('sum')

date_2017=crsp_factors[crsp_factors["yearmonth"] == "2017-01"].copy()

table_B5= date_2017[["permno","w_vw"]]
print("Table B5")
print(table_B5)
# Out:
# Table B5
#       permno      w_vw
# 24     10026  0.003449
# 144    10032  0.002507
# 264    10044  0.000082
# 384    10065  0.001705
# 504    10104  0.218091
# 624    10107  0.664140
# 744    10318  0.003685
# 864    10333  0.000036
# 984    12079  0.073555
# 1104   21020  0.032749

# %% [markdown]
# Question 7

# %%
crsp_factors['ret_vw'] = (crsp_factors['ret'] * crsp_factors['w_vw']).groupby(crsp_factors['date']).transform('sum')

portfolio_stats = crsp_factors.groupby('date')[['ret_vw', 'rf']].first().reset_index()


# - compute mean and std dev
vw_mean = portfolio_stats['ret_vw'].mean()
vw_mean_ex = vw_mean - rf_mean_subsample
vw_std = portfolio_stats['ret_vw'].std()

vw_monthly_sharpe_ratio_portfolio = vw_mean_ex / vw_std
vw_annualized_sharpe_ratio_portfolio = vw_monthly_sharpe_ratio_portfolio * np.sqrt(12)

print("Value weighted mean monthly excess return:", vw_mean_ex)
print("Annualized Sharpe ratio:", vw_annualized_sharpe_ratio_portfolio)
# Out:
# Value weighted mean monthly excess return: 0.01788100176379836
# Annualized Sharpe ratio: 1.1131531573701579

# %%
crsp_factors.head()
# Out:
#      permno       date tsymbol                            comnam    prc  \
# 0     10026 2015-01-30    JJSF            J & J SNACK FOODS CORP  98.12
# 120   10032 2015-01-30    PLXS                       PLEXUS CORP  37.89
# 240   10044 2015-01-30    RMCF  ROCKY MOUNTAIN CHOCOLATE FAC INC  13.63
# 360   10065 2015-01-30     ADX                  ADAMS EXPRESS CO  13.39
# 480   10104 2015-01-30    ORCL                       ORACLE CORP  41.89
#
#           ret        vol     shrout yearmonth   mktrf  ...     cma   rf  \
# 0   -0.097913    15844.0    18688.0   2015-01 -0.0309  ... -0.0164  0.0
# 120 -0.080563    43222.0    33548.0   2015-01 -0.0309  ... -0.0164  0.0
# 240  0.038872     3910.0     6093.0   2015-01 -0.0309  ... -0.0164  0.0
# 360 -0.021199    28936.0    93509.0   2015-01 -0.0309  ... -0.0164  0.0
# 480 -0.065822  3143875.0  4391367.0   2015-01 -0.0309  ... -0.0164  0.0
#
#         mom     retex  w_ew   ret_ew      mktcap  mktcap_l1  w_vw  ret_vw
# ...

# %% [markdown]
# Question 9

# %%
# Import libraries needed for linear regression
from statsmodels.regression.linear_model import OLS
from statsmodels.tools import add_constant

# Run a linear regression via statsmodels
# - select one stock for the regression (since we are running time-series regression)
reg_data = crsp_factors[crsp_factors['permno'] == 10107]
# - drop rows with missing values
reg_data = reg_data.dropna(subset=['retex','mktrf'])

# Define dependent and independent variables
X = add_constant(reg_data['mktrf'])
y = reg_data['retex']
print(X.shape)
print(y.shape)

# Fit the OLS regression
# - compute Newey-West standard errors with automatic lag selection
model = OLS(y, X).fit(cov_type='HAC', cov_kwds={'maxlags': None})
# - under i.i.d. errors:
# model = OLS(y, X).fit()

# Print the regression results summary
print("Microsoft regression output:")
print(model.summary())
# Out:
# (120, 2)
# (120,)
# Microsoft regression output:
#                             OLS Regression Results
# ...
# Dep. Variable:                  retex   R-squared:                       0.450
# Model:                            OLS   Adj. R-squared:                  0.446
# Method:                 Least Squares   F-statistic:                     100.2
# Date:                Tue, 16 Dec 2025   Prob (F-statistic):           1.89e-17
# Time:                        08:33:45   Log-Likelihood:                 197.52
# No. Observations:                 120   AIC:                            -391.0
# Df Residuals:                     118   BIC:                            -385.5
# Df Model:                           1
# Covariance Type:                  HAC
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0113      0.004      2.807      0.005       0.003       0.019
# ...

# %%
# Import libraries needed for linear regression
from statsmodels.regression.linear_model import OLS
from statsmodels.tools import add_constant

# Run a linear regression via statsmodels
# - select one stock for the regression (since we are running time-series regression)
reg_data = crsp_factors[crsp_factors['permno'] == 12079]
# - drop rows with missing values
reg_data = reg_data.dropna(subset=['retex','mktrf'])

# Define dependent and independent variables
X = add_constant(reg_data['mktrf'])
y = reg_data['retex']
print(X.shape)
print(y.shape)

# Fit the OLS regression
# - compute Newey-West standard errors with automatic lag selection
model = OLS(y, X).fit(cov_type='HAC', cov_kwds={'maxlags': None})
# - under i.i.d. errors:
# model = OLS(y, X).fit()

# Print the regression results summary
print("General Motors regression output:")
print(model.summary())
# Out:
# (120, 2)
# (120,)
# General Motors regression output:
#                             OLS Regression Results
# ...
# Dep. Variable:                  retex   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.444
# Method:                 Least Squares   F-statistic:                     111.5
# Date:                Tue, 16 Dec 2025   Prob (F-statistic):           9.33e-19
# Time:                        08:33:45   Log-Likelihood:                 146.59
# No. Observations:                 120   AIC:                            -289.2
# Df Residuals:                     118   BIC:                            -283.6
# Df Model:                           1
# Covariance Type:                  HAC
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0049      0.006     -0.814      0.416      -0.017       0.007
# ...

# %%
# Import libraries needed for linear regression
from statsmodels.regression.linear_model import OLS
from statsmodels.tools import add_constant

# Run a linear regression via statsmodels
# - select one stock for the regression (since we are running time-series regression)
reg_data = crsp_factors[crsp_factors['permno'] == 21020]
# - drop rows with missing values
reg_data = reg_data.dropna(subset=['retex','mktrf'])

# Define dependent and independent variables
X = add_constant(reg_data['mktrf'])
y = reg_data['retex']
print(X.shape)
print(y.shape)

# Fit the OLS regression
# - compute Newey-West standard errors with automatic lag selection
model = OLS(y, X).fit(cov_type='HAC', cov_kwds={'maxlags': None})
# - under i.i.d. errors:
# model = OLS(y, X).fit()

# Print the regression results summary
print("American Airline regression ouput:")
print(model.summary())
# Out:
# (120, 2)
# (120,)
# American Airline regression ouput:
#                             OLS Regression Results
# ...
# Dep. Variable:                  retex   R-squared:                       0.305
# Model:                            OLS   Adj. R-squared:                  0.300
# Method:                 Least Squares   F-statistic:                     55.94
# Date:                Tue, 16 Dec 2025   Prob (F-statistic):           1.45e-11
# Time:                        08:33:45   Log-Likelihood:                 108.52
# No. Observations:                 120   AIC:                            -213.0
# Df Residuals:                     118   BIC:                            -207.5
# Df Model:                           1
# Covariance Type:                  HAC
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0172      0.010     -1.777      0.076      -0.036       0.002
# ...

# %% [markdown]
# Question 10

# %%
# Run a linear regression via statsmodels
# - select one stock for the regression (since we are running time-series regression)
reg_data = crsp_factors[crsp_factors['permno'] == 10107]
# - drop rows with missing values
reg_data = reg_data.dropna(subset=['retex','mktrf','smb','hml','rmw','cma','mom'])

# Define dependent and independent variables
X = add_constant(reg_data[['mktrf','smb','hml','rmw','cma','mom']])
y = reg_data['retex']
print(X.shape)
print(y.shape)

# Fit the OLS regression
# - compute Newey-West standard errors with automatic lag selection
model = OLS(y, X).fit(cov_type='HAC', cov_kwds={'maxlags': None})
# - under i.i.d. errors:
# model = OLS(y, X).fit()

# Print the regression results summary
print("Microsoft regression output:")
print(model.summary())
# Out:
# (120, 7)
# (120,)
# Microsoft regression output:
#                             OLS Regression Results
# ...
# Dep. Variable:                  retex   R-squared:                       0.623
# Model:                            OLS   Adj. R-squared:                  0.603
# Method:                 Least Squares   F-statistic:                     66.66
# Date:                Tue, 16 Dec 2025   Prob (F-statistic):           7.80e-35
# Time:                        08:33:45   Log-Likelihood:                 220.16
# No. Observations:                 120   AIC:                            -426.3
# Df Residuals:                     113   BIC:                            -406.8
# Df Model:                           6
# Covariance Type:                  HAC
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0089      0.003      2.558      0.011       0.002       0.016
# ...

# %%
# Run a linear regression via statsmodels
# - select one stock for the regression (since we are running time-series regression)
reg_data = crsp_factors[crsp_factors['permno'] == 12079]
# - drop rows with missing values
reg_data = reg_data.dropna(subset=['retex','mktrf','smb','hml','rmw','cma','mom'])

# Define dependent and independent variables
X = add_constant(reg_data[['mktrf','smb','hml','rmw','cma','mom']])
y = reg_data['retex']
print(X.shape)
print(y.shape)

# Fit the OLS regression
# - compute Newey-West standard errors with automatic lag selection
model = OLS(y, X).fit(cov_type='HAC', cov_kwds={'maxlags': None})
# - under i.i.d. errors:
# model = OLS(y, X).fit()

# Print the regression results summary
print("General Motors regression output:")
print(model.summary())
# Out:
# (120, 7)
# (120,)
# General Motors regression output:
#                             OLS Regression Results
# ...
# Dep. Variable:                  retex   R-squared:                       0.535
# Model:                            OLS   Adj. R-squared:                  0.511
# Method:                 Least Squares   F-statistic:                     38.50
# Date:                Tue, 16 Dec 2025   Prob (F-statistic):           3.72e-25
# Time:                        08:33:46   Log-Likelihood:                 156.82
# No. Observations:                 120   AIC:                            -299.6
# Df Residuals:                     113   BIC:                            -280.1
# Df Model:                           6
# Covariance Type:                  HAC
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0006      0.006     -0.109      0.913      -0.012       0.011
# ...

# %%
# Run a linear regression via statsmodels
# - select one stock for the regression (since we are running time-series regression)
reg_data = crsp_factors[crsp_factors['permno'] == 21020]
# - drop rows with missing values
reg_data = reg_data.dropna(subset=['retex','mktrf','smb','hml','rmw','cma','mom'])

# Define dependent and independent variables
X = add_constant(reg_data[['mktrf','smb','hml','rmw','cma','mom']])
y = reg_data['retex']
print(X.shape)
print(y.shape)

# Fit the OLS regression
# - compute Newey-West standard errors with automatic lag selection
model = OLS(y, X).fit(cov_type='HAC', cov_kwds={'maxlags': None})
# - under i.i.d. errors:
# model = OLS(y, X).fit()

# Print the regression results summary
print("American Airlines regression output:")
print(model.summary())
# Out:
# (120, 7)
# (120,)
# American Airlines regression output:
#                             OLS Regression Results
# ...
# Dep. Variable:                  retex   R-squared:                       0.385
# Model:                            OLS   Adj. R-squared:                  0.353
# Method:                 Least Squares   F-statistic:                     18.85
# Date:                Tue, 16 Dec 2025   Prob (F-statistic):           4.19e-15
# Time:                        08:33:46   Log-Likelihood:                 115.84
# No. Observations:                 120   AIC:                            -217.7
# Df Residuals:                     113   BIC:                            -198.2
# Df Model:                           6
# Covariance Type:                  HAC
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
